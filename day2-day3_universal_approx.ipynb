# %%
from typing import Union
import warnings
warnings.filterwarnings('ignore')

import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

import torch
import torch.utils.data as data
import torch.nn as nn
import torch.optim as optim

# %%
class Dataset(data.Dataset):

    def __init__(self, X: np.array, y: np.array):
        self.X, self.y = X, y

    def __len__(self):
        return self.X.shape[0]

    def __getitem__(self, idx):
        return self.X[idx, :], self.y[idx]

def data_loaders(X: Union[np.ndarray, torch.Tensor], y: Union[np.ndarray, torch.Tensor], test_size: float = 0.2, random_state: Union[int, None] = None, batch_size: int = 32, *args, **kwargs):

    assert X.shape[0] == y.shape[0]

    if isinstance(X, np.ndarray):
        X = torch.Tensor(X)
    if isinstance(y, np.ndarray):
        y = torch.Tensor(y)

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, shuffle=True, random_state=random_state)
    train_loader = data.DataLoader(
        dataset=Dataset(X_train, y_train),
        batch_size=batch_size,
        shuffle=True
    )
    test_loader = data.DataLoader(
        dataset=Dataset(X_test, y_test),
        batch_size=batch_size,
        shuffle=True
    )

    return train_loader, test_loader

# %%
class FNN(nn.Module):

    def __init__(self, n_hidden_layers_sizes: Union[int, list] = 1, activation: str = 'sigmoid', *args, **kwargs):

        super(FNN, self).__init__()

        if isinstance(n_hidden_layers_sizes, int):
            n_hidden_layers_sizes = [n_hidden_layers_sizes]
        if not isinstance(n_hidden_layers_sizes, list):
            raise ValueError(f'n_hidden_layers_sizes should be of type int or list, instead received {n_hidden_layers_sizes} of type {type(n_hidden_layers_sizes)}.')
        
        n_hidden_layers_sizes = [1] + n_hidden_layers_sizes + [1]
        self.dense_layers = nn.ModuleList([
            nn.Linear(input_size, output_size) 
            for input_size, output_size in zip(n_hidden_layers_sizes[:-1], n_hidden_layers_sizes[1:])
        ])

        if activation.lower() == 'relu':
            self.activation = nn.ReLU()
        elif activation.lower() == 'gelu':
            self.activation = nn.GELU()
        elif activation.lower() == 'sigmoid':
            self.activation = nn.Sigmoid()
        else:
            raise ValueError(f'activation must be one of relu, gelu or sigmoid, instead received {activation}')

    def forward(self, x: torch.Tensor):

        for layer in self.dense_layers[:-1]:
            # x = self.activation(layer(x))
            x = layer(x)

        output = self.dense_layers[-1](x)

        return output

# %%
def train(model, train_loader, criterion, optimizer, scheduler, to_print):
    
    model.train()
    train_loss = []
    
    for X, y in train_loader:
        
        X = X.requires_grad_() 
        optimizer.zero_grad()
        output = model(X)
        loss = criterion(output, y)
        train_loss.append(loss.item())

        loss.backward()
        optimizer.step()
        scheduler.step()

    avg_train_loss = torch.mean(torch.tensor(train_loss))

    if to_print:
        print(f'Average training loss = {avg_train_loss:.4f}', end=', ')
    
    return avg_train_loss

def test(model, train_loader, criterion, to_print):
    
    model.eval()
    test_loss = []
    
    for data in train_loader:
        
        X, y = data 
        output = model(X)
        loss = criterion(output, y)
        test_loss.append(loss.item())

    avg_test_loss = torch.mean(torch.tensor(test_loss))

    if to_print:
        print(f'Average validation loss = {avg_test_loss:.4f}')
    
    return avg_test_loss

# %%
def main(X: np.ndarray, y1: np.ndarray, test_size: float = 0.2, batch_size: int = 32, n_hidden_layers_sizes: Union[int, list] = [3, 3], activation: str = 'sigmoid', epochs: int = 100, lr: float = 2e-4):

    assert isinstance(test_size, float) and 0 < test_size < 1
    assert isinstance(batch_size, int) and batch_size > 0
    assert isinstance(activation, str) and activation in ('sigmoid', 'ReLU', 'GELU')
    assert isinstance(epochs, int) and epochs > 0
    assert isinstance(lr, float) and 0 < lr

    y = y1 # + np.random.normal(0, 0.1, X.shape[0])
    train_loader, test_loader = data_loaders(X, y, test_size=test_size, batch_size=batch_size)

    model = FNN(n_hidden_layers_sizes=n_hidden_layers_sizes, activation=activation)

    optimizer = optim.AdamW(model.parameters(), lr)
    criterion = nn.MSELoss()
    scheduler = optim.lr_scheduler.OneCycleLR(
        optimizer, 
        max_lr=lr, 
        steps_per_epoch=len(train_loader),
        epochs=epochs,
        anneal_strategy='linear'
    )

    train_stats, test_stats = [], []

    for epoch in range(1, epochs+1):

        to_print = not bool(epoch%5)
        if to_print:
            print(f'Epoch: {epoch}', end=' - ')

        train_loss = train(model, train_loader, criterion, optimizer, scheduler, to_print)
        test_loss = test(model, test_loader, criterion, to_print)

        train_stats.append(train_loss)
        test_stats.append(test_loss)

    return model, train_stats, test_stats

# %%
def plot(X, y1, model, train_stats, test_stats):

    fontdict = {'family':'serif', 'color':'darkred', 'weight':'normal', 'size':16}
    labelpad = titlepad = 12

    _, axs = plt.subplots(1, 2, figsize=(16, 6))
    axs[0].set_xlabel('Epochs', fontdict=fontdict, labelpad=labelpad)
    axs[0].set_ylabel('Loss', fontdict=fontdict, labelpad=labelpad)
    axs[0].set_title('Training Loss and Test Loss', fontdict=fontdict, pad=titlepad)
    axs[0].plot(train_stats, color='g', label='Training')
    axs[0].plot(test_stats, color='b', label='Validation')
    axs[0].legend(loc='upper right')
    axs[0].grid()

    X = torch.Tensor(X.reshape((-1, 1)))
    y2 = model(X).detach().numpy()

    axs[1].set_xlabel('X', fontdict=fontdict, labelpad=labelpad)
    axs[1].set_ylabel('Y', fontdict=fontdict, labelpad=labelpad)
    axs[1].set_title('True Value and Model Predictions', fontdict=fontdict, pad=titlepad)
    axs[1].plot(X, y1, color='g', label='True Value')
    axs[1].plot(X, y2, color='b', label='Model Predictions')
    axs[1].legend(loc='upper right')
    axs[1].grid()

# %%
'''a, b, c, d = np.random.normal(loc=0, scale=2, size=4)
transform = np.vectorize(lambda x: a * np.sin(b*x + c) + d)

X = np.random.uniform(-10, 10, 1000).reshape((-1, 1))
y1 = transform(X)
model, train_stats, test_stats = main(X, y1, n_hidden_layers_sizes=[5, 5], epochs=100, lr=2e-5)

X = np.linspace(-10, 10, 1000)
y1 = transform(X)
plot(X, y1, model, train_stats, test_stats)'''
# Out:
# Epoch: 5 - Average training loss = 9.2871, Average validation loss = 8.9257
# Epoch: 10 - Average training loss = 9.2701, Average validation loss = 9.1330
# Epoch: 15 - Average training loss = 9.2429, Average validation loss = 9.3555
# Epoch: 20 - Average training loss = 9.2059, Average validation loss = 8.8870
# Epoch: 25 - Average training loss = 9.1597, Average validation loss = 8.8226
# Epoch: 30 - Average training loss = 9.1054, Average validation loss = 8.8661
# Epoch: 35 - Average training loss = 9.0485, Average validation loss = 9.0426
# Epoch: 40 - Average training loss = 8.9972, Average validation loss = 8.5220
# Epoch: 45 - Average training loss = 8.9510, Average validation loss = 8.6503
# Epoch: 50 - Average training loss = 8.9098, Average validation loss = 8.4983
# Epoch: 55 - Average training loss = 8.8732, Average validation loss = 8.6730
# Epoch: 60 - Average training loss = 8.8407, Average validation loss = 8.8294
# Epoch: 65 - Average training loss = 8.8124, Average validation loss = 8.5891
# Epoch: 70 - Average training loss = 8.7880, Average validation loss = 8.4524
# Epoch: 75 - Average training loss = 8.7675, Average validation loss = 8.3565
# Epoch: 80 - Average training loss = 8.7506, Average validation loss = 7.8432
# Epoch: 85 - Average training loss = 8.7376, Average validation loss = 8.3903
# Epoch: 90 - Average training loss = 8.7281, Average validation loss = 8.7945
# Epoch: 95 - Average training loss = 8.7223, Average validation loss = 8.4682
# Epoch: 100 - Average training loss = 8.7202, Average validation loss = 9.1613

# %%
a, b, c, d = np.random.normal(loc=0, scale=2, size=4)
transform = np.vectorize(lambda x: a*x + b)

X = np.random.uniform(-10, 10, 10000).reshape((-1, 1))
y1 = transform(X)
model, train_stats, test_stats = main(X, y1, n_hidden_layers_sizes=[1], epochs=100, lr=2e-5)

X = np.linspace(-10, 10, 1000)
y1 = transform(X)
plot(X, y1, model, train_stats, test_stats)
# Out:
# Epoch: 5 - Average training loss = 519.9698, Average validation loss = 504.9275
# Epoch: 10 - Average training loss = 517.6061, Average validation loss = 503.1052
# Epoch: 15 - Average training loss = 513.8994, Average validation loss = 498.7370
# Epoch: 20 - Average training loss = 508.9539, Average validation loss = 492.9894
# Epoch: 25 - Average training loss = 502.8706, Average validation loss = 486.8982
# Epoch: 30 - Average training loss = 495.7957, Average validation loss = 480.1834
# Epoch: 35 - Average training loss = 488.5865, Average validation loss = 473.2729
# Epoch: 40 - Average training loss = 482.1956, Average validation loss = 466.2996
# Epoch: 45 - Average training loss = 476.5585, Average validation loss = 462.7996
# Epoch: 50 - Average training loss = 471.6103, Average validation loss = 456.8086
# Epoch: 55 - Average training loss = 467.2932, Average validation loss = 452.7227
# Epoch: 60 - Average training loss = 463.5472, Average validation loss = 451.5850
# Epoch: 65 - Average training loss = 460.3280, Average validation loss = 447.0484
# Epoch: 70 - Average training loss = 457.6039, Average validation loss = 442.9723
# Epoch: 75 - Average training loss = 455.3472, Average validation loss = 441.5417
# Epoch: 80 - Average training loss = 453.5246, Average validation loss = 440.9084
# Epoch: 85 - Average training loss = 452.1172, Average validation loss = 437.6179
# Epoch: 90 - Average training loss = 451.1083, Average validation loss = 437.8169
# Epoch: 95 - Average training loss = 450.4973, Average validation loss = 437.7062
# Epoch: 100 - Average training loss = 450.2686, Average validation loss = 436.7144
